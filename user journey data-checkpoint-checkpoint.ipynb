# %% [markdown]
# # Project Documentation: Extracting User Journey Data with SQL

# %% [markdown]
# ## Introduction
# This project is centered on analyzing the pre-purchase behavior of users to understand their journey across the company's front-end web pages. By examining interactions from various sessions leading to a purchase, the project aims to provide insights into how users navigate the platform before making their first subscription purchase. The extracted user journey data will serve as a key resource for marketing teams to improve customer experience and optimize conversion rates.
#
# The project utilizes a dataset that includes three main tables:
#
# student_purchases: Contains records of user payments and purchase types.
# front_visitors: Links visitors with their user IDs.
# front_interactions: Logs visitor activities, including page visits, clicks, and other interactions.

# %% [markdown]
# ## Project Objectives
# The key objectives of this project are:
#
# To identify users who made their first subscription purchase between January 1, 2023, and March 31, 2023.
#
# To extract the sequence of web pages visited by each user before their first purchase.
#
# To group all visited pages into a user journey string for each session.
#
# To filter out test users (who paid $0 for their subscriptions).
#
# To replace raw URLs with readable aliases for better clarity.

# %% [markdown]
# ## Project Requirements
# The SQL database provided contains user interactions, purchase records, and visitor mappings. The following tools and resources were used:
#
# MySQL Workbench 8.0 or later: Required for database management and query execution.
#
# Database schema: Generated using the User_Journey_Database.sql file provided, which includes the following tables:
#
# student_purchases, front_visitors, and front_interactions.
#
# URL_Aliases.xlsx: A reference file containing URL aliases to replace long URLs with simplified names.

# %% [markdown]
# ## Data Overview
# The database consists of the following key components:
#
# student_purchases: Contains user purchase data, including user_id, purchase_type, purchase_price, and date_purchased. Only users with a purchase date in Q1 2023 and a purchase price greater than $0 are included.
#
# front_visitors: Maps visitor_id to user_id. Users who never made a purchase have no associated user_id and are excluded.
#
# front_interactions: Records all interactions (e.g., page visits) made by visitors. Each entry includes a visitor_id, session_id, event_source_url, event_destination_url, and event_date.

# %% [markdown]
# ## Analysis Approach
# The project follows a structured approach using SQL queries to extract the desired user journey data:
#
# Step 1: Filter Subscription Data
# Identify users who made their first subscription purchase between January 1, 2023, and March 31, 2023.
# Exclude test users by filtering out those with a purchase price of $0.
# Classify the subscription types as 'monthly', 'quarterly', or 'annual'.
#
# Step 2: Join Interaction Data
# Using the user_id from the filtered purchase data, join the interaction data to extract all web events for these users before their first purchase date.
#
# Step 3: Create URL Aliases
# Use the provided URL aliases to simplify event source and destination URLs.
# Replace long URLs with human-readable names, such as "Homepage", "Login", "Sign up", "Courses", etc.
#
# Step 4: Concatenate User Journeys
# Combine the source and destination URLs of each user interaction within a session into a single string.
# Use the GROUP_CONCAT function to concatenate all interactions in a session into one journey string, separating each page visit with a hyphen (-).
#
# Step 5: Output User Journeys
# Generate a final output containing the following columns: user_id, session_id, subscription_type, and user_journey.
# The user_journey column contains the ordered sequence of pages visited by the user before making their first purchase.

# %% [markdown]
# ## connecting to the database

# %%
# %load_ext sql

# %sql mysql+pymysql://root:100200300@localhost:3306/user_journey_data

# %% [markdown]
# ## CODE

# %%
# %%sql
#
# ## Create a CTE to filter users who made their first purchase in Q1 2023
# SET SESSION group_concat_max_len = 100000;
# SET sql_mode = (SELECT REPLACE(@@sql_mode, 'ONLY_FULL_GROUP_BY', ''));
#
# WITH subscription_data AS (
#     SELECT
#         user_id,
#         MIN(date_purchased) AS first_purchase_date,
#         IF(purchase_type = 0, 'monthly',
#            IF(purchase_type = 1, 'quarterly',
#            IF(purchase_type = 2, 'annual', 'other'))) AS subscription_type,
#         purchase_price
#     FROM student_purchases
#     GROUP BY user_id
#     HAVING CAST(first_purchase_date AS DATE) >= '2023-01-01'
#     AND CAST(first_purchase_date AS DATE) < '2023-03-01'
#     AND purchase_price > 0
# ),
#
# ## Join the filtered user data with their interactions prior to the purchase date
# interactio_student_data AS (
#     SELECT
#         sd.user_id, front_interactions.visitor_id, session_id, event_source_url, event_destination_url, subscription_type
#     FROM subscription_data AS sd
#     INNER JOIN front_visitors ON front_visitors.user_id = sd.user_id
#     INNER JOIN front_interactions ON front_interactions.visitor_id = front_visitors.visitor_id
#     WHERE event_date < first_purchase_date
#     ),
#
# ## Replace long URLs with aliases for easier readability
# modified_url AS (
#     SELECT
#         user_id, session_id, subscription_type,
#         CASE
#           WHEN event_source_url = 'https://365datascience.com/' THEN 'Homepage'
#           WHEN event_source_url LIKE 'https://365datascience.com/login/%' THEN 'Log in'
#           WHEN event_source_url LIKE 'https://365datascience.com/signup/%' THEN 'Sign up'
#           WHEN event_source_url LIKE 'https://365datascience.com/resources-center/%' THEN 'Resources center'
#           WHEN event_source_url LIKE 'https://365datascience.com/courses/%' THEN 'Courses'
#           WHEN event_source_url LIKE 'https://365datascience.com/career-tracks/%' THEN 'Career tracks'
#           WHEN event_source_url LIKE 'https://365datascience.com/upcoming-courses/%' THEN 'Upcoming courses'
#           WHEN event_source_url LIKE 'https://365datascience.com/career-track-certificate/%' THEN 'Career track certificate'
#           WHEN event_source_url LIKE 'https://365datascience.com/course-certificate/%' THEN 'Course certificate'
#           WHEN event_source_url LIKE 'https://365datascience.com/success-stories/%' THEN 'Success stories'
#           WHEN event_source_url LIKE 'https://365datascience.com/blog/%' THEN 'Blog'
#           WHEN event_source_url LIKE 'https://365datascience.com/pricing/%' THEN 'Pricing'
#           WHEN event_source_url LIKE 'https://365datascience.com/about-us/%' THEN 'About us'
#           WHEN event_source_url LIKE 'https://365datascience.com/instructors/%' THEN 'Instructors'
#           WHEN event_source_url LIKE 'https://365datascience.com/checkout/%' AND event_source_url LIKE '%coupon%' THEN 'Coupon'
#           WHEN event_source_url LIKE 'https://365datascience.com/checkout/%' AND event_source_url NOT LIKE '%coupon%' THEN 'Checkout'
#           ELSE 'Other'
#         END AS user_url,
#
#         CASE
#               WHEN event_source_url = 'https://365datascience.com/' THEN 'Homepage'
#               WHEN event_source_url LIKE 'https://365datascience.com/login/%' THEN 'Log in'
#               WHEN event_source_url LIKE 'https://365datascience.com/signup/%' THEN 'Sign up'
#               WHEN event_source_url LIKE 'https://365datascience.com/resources-center/%' THEN 'Resources center'
#               WHEN event_source_url LIKE 'https://365datascience.com/courses/%' THEN 'Courses'
#               WHEN event_source_url LIKE 'https://365datascience.com/career-tracks/%' THEN 'Career tracks'
#               WHEN event_source_url LIKE 'https://365datascience.com/upcoming-courses/%' THEN 'Upcoming courses'
#               WHEN event_source_url LIKE 'https://365datascience.com/career-track-certificate/%' THEN 'Career track certificate'
#               WHEN event_source_url LIKE 'https://365datascience.com/course-certificate/%' THEN 'Course certificate'
#               WHEN event_source_url LIKE 'https://365datascience.com/success-stories/%' THEN 'Success stories'
#               WHEN event_source_url LIKE 'https://365datascience.com/blog/%' THEN 'Blog'
#               WHEN event_source_url LIKE 'https://365datascience.com/pricing/%' THEN 'Pricing'
#               WHEN event_source_url LIKE 'https://365datascience.com/about-us/%' THEN 'About us'
#               WHEN event_source_url LIKE 'https://365datascience.com/instructors/%' THEN 'Instructors'
#               WHEN event_source_url LIKE 'https://365datascience.com/checkout/%' AND event_source_url LIKE '%coupon%' THEN 'Coupon'
#               WHEN event_source_url LIKE 'https://365datascience.com/checkout/%' AND event_source_url NOT LIKE '%coupon%' THEN 'Checkout'
#               ELSE 'Other'
#         END AS destination_url
#     FROM interactio_student_data
# ),
#
# ## Concatenate source and destination URLs for each interaction
# combined_pages AS(
#     SELECT user_id,session_id, subscription_type, CONCAT(user_url, "-",destination_url) as combined_page
#     FROM modified_url
# ),
#
# ## Combine all pages visited in each session into a single string for the user journey
# session_pages AS (
#     SELECT
#         user_id, session_id, subscription_type,
#         GROUP_CONCAT(combined_page SEPARATOR '-') as user_journey
#     FROM combined_pages
#     GROUP BY session_id
# )
#
# #Select the final data, including user_id, session_id, subscription_type, and user_journey
# SELECT * FROM session_pages ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/user_journey_data
# 0 rows affected.
# 0 rows affected.
# 4563 rows affected.
# [(392228, 2807280, 'annual', 'Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate'),
#  (455204, 2810317, 'monthly', 'Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (339582, 2811543, 'annual', 'Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Career tracks-Career tracks'),
#  (455204, 2811548, 'monthly', 'Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (339582, 2812935, 'annual', 'Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (349826, 2816745, 'annual', 'Log in-Log in-Log in-Log in'),
#  (349826, 2816779, 'annual', 'Checkout-Checkout-Checkout-Checkout'),
#  (339582, 2816825, 'annual', 'Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Courses-Courses-Courses-Courses'),
#  (398805, 2817165, 'monthly', 'Log in-Log in'),
#  (455234, 2818226, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (455234, 2818313, 'annual', 'Sign up-Sign up-Sign up-Sign up'),
#  (454666, 2818377, 'annual', 'Log in-Log in'),
#  (454666, 2818443, 'annual', 'Checkout-Checkout'),
#  (331693, 2819402, 'monthly', 'Log in-Log in'),
#  (424647, 2819508, 'annual', 'Log in-Log in'),
#  (467499, 2819537, 'annual', 'Log in-Log in'),
#  (467499, 2819674, 'annual', 'Log in-Log in-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (339582, 2820517, 'annual', 'Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career tracks-Career tracks-Courses-Courses-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (448776, 2822226, 'annual', 'Checkout-Checkout'),
#  (387096, 2827209, 'annual', 'Log in-Log in'),
#  (318200, 2828150, 'annual', 'Log in-Log in'),
#  (411785, 2830280, 'annual', 'Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate ... (237 characters truncated) ... k certificate-Career track certificate-Career track certificate-Career tracks-Career tracks-Career tracks-Career tracks-Sign up-Sign up-Log in-Log in'),
#  (282927, 2830514, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (282927, 2830583, 'annual', 'Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon'),
#  (455343, 2831102, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (267955, 2837493, 'annual', 'Log in-Log in'),
#  (396099, 2837540, 'annual', 'Career tracks-Career tracks-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (313048, 2837563, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (392228, 2839591, 'annual', 'Pricing-Pricing'),
#  (392228, 2839690, 'annual', 'Upcoming courses-Upcoming courses'),
#  (318200, 2841785, 'annual', 'Log in-Log in'),
#  (256301, 2842693, 'monthly', 'Homepage-Homepage-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificat ... (139 characters truncated) ... eer track certificate-Career track certificate-Career track certificate-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Log in-Log in'),
#  (318200, 2842923, 'annual', 'Log in-Log in'),
#  (409923, 2843377, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Pricing-Pricing-Courses-Courses-Course certificate-Course certificate-Courses-Courses-Courses-Courses-Courses-Courses-Course certificate-Course certificate'),
#  (444322, 2843600, 'quarterly', 'Homepage-Homepage-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (430496, 2845031, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (455568, 2847176, 'annual', 'Homepage-Homepage-Pricing-Pricing-Homepage-Homepage-Log in-Log in'),
#  (455568, 2847193, 'annual', 'Log in-Log in-Log in-Log in'),
#  (343534, 2847510, 'monthly', 'Log in-Log in'),
#  (455568, 2847847, 'annual', 'Log in-Log in-Log in-Log in-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (371779, 2849976, 'annual', 'Homepage-Homepage-Pricing-Pricing-Pricing-Pricing-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (355056, 2851058, 'annual', 'Homepage-Homepage-Pricing-Pricing-Pricing-Pricing-Resources center-Resources center'),
#  (360808, 2852693, 'monthly', 'Log in-Log in'),
#  (343534, 2853497, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (455122, 2856295, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (455122, 2856575, 'annual', 'Log in-Log in-Log in-Log in'),
#  (455122, 2858922, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (331693, 2860531, 'monthly', 'Log in-Log in'),
#  (354201, 2861847, 'annual', 'Log in-Log in'),
#  (312454, 2863342, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in'),
#  (462670, 2864824, 'quarterly', 'Homepage-Homepage-Homepage-Homepage-Pricing-Pricing-Sign up-Sign up-Sign up-Sign up'),
#  (312454, 2865408, 'monthly', 'Homepage-Homepage-Course certificate-Course certificate-Pricing-Pricing'),
#  (312454, 2865414, 'monthly', 'Pricing-Pricing-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (312454, 2865426, 'monthly', 'Log in-Log in'),
#  (324442, 2866063, 'monthly', 'Log in-Log in'),
#  (334108, 2866522, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (343619, 2866540, 'annual', 'Checkout-Checkout'),
#  (343619, 2866555, 'annual', 'Homepage-Homepage-Pricing-Pricing'),
#  (459170, 2867048, 'annual', 'Other-Other-Courses-Courses'),
#  (459170, 2867058, 'annual', 'Courses-Courses-Courses-Courses'),
#  (459170, 2867063, 'annual', 'Courses-Courses-Pricing-Pricing'),
#  (455568, 2867583, 'annual', 'Log in-Log in'),
#  (360808, 2868957, 'monthly', 'Log in-Log in'),
#  (360808, 2868959, 'monthly', 'Log in-Log in'),
#  (273256, 2869318, 'annual', 'Homepage-Homepage'),
#  (273256, 2869646, 'annual', 'Sign up-Sign up-Log in-Log in'),
#  (273256, 2869675, 'annual', 'Log in-Log in'),
#  (454131, 2870363, 'annual', 'Homepage-Homepage-Pricing-Pricing-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (454131, 2870379, 'annual', 'Checkout-Checkout'),
#  (305842, 2870550, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in'),
#  (467448, 2875173, 'annual', 'Homepage-Homepage-Career tracks-Career tracks-Homepage-Homepage-Career tracks-Career tracks-Homepage-Homepage-Homepage-Homepage-Career tracks-Career tracks-Homepage-Homepage'),
#  (456100, 2876294, 'annual', 'Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (334108, 2877598, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (353669, 2879553, 'monthly', 'Log in-Log in'),
#  (120485, 2882468, 'monthly', 'Homepage-Homepage-Homepage-Homepage-Log in-Log in'),
#  (462449, 2882986, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses'),
#  (345526, 2884760, 'monthly', 'Log in-Log in'),
#  (456261, 2887458, 'monthly', 'Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (456277, 2888710, 'annual', 'Other-Other'),
#  (456277, 2888781, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (269209, 2888863, 'annual', 'Log in-Log in'),
#  (392285, 2888932, 'monthly', 'Log in-Log in-Log in-Log in'),
#  (345526, 2889667, 'monthly', 'Checkout-Checkout'),
#  (319493, 2891137, 'annual', 'Log in-Log in-Log in-Log in'),
#  (354683, 2891653, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in'),
#  (427084, 2894352, 'monthly', 'Homepage-Homepage-Pricing-Pricing-Log in-Log in'),
#  (338632, 2895431, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (358019, 2901215, 'annual', 'Log in-Log in'),
#  (402831, 2901468, 'annual', 'Log in-Log in'),
#  (402831, 2901471, 'annual', 'Log in-Log in'),
#  (387096, 2902181, 'annual', 'Homepage-Homepage-Sign up-Sign up-Log in-Log in'),
#  (345526, 2902507, 'monthly', 'Checkout-Checkout'),
#  (307886, 2903454, 'monthly', 'Homepage-Homepage-Pricing-Pricing'),
#  (312849, 2905669, 'annual', 'Pricing-Pricing-Log in-Log in'),
#  (455568, 2906262, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (343534, 2909390, 'monthly', 'Log in-Log in'),
#  (454272, 2909974, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (338632, 2910995, 'monthly', 'Homepage-Homepage-Homepage-Homepage-Homepage-Homepage'),
#  (331693, 2913255, 'monthly', 'Log in-Log in'),
#  (331693, 2913279, 'monthly', 'Log in-Log in'),
#  (448776, 2914875, 'annual', 'Log in-Log in-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Log in-Log in-Log in-Log in-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (345526, 2915769, 'monthly', 'Homepage-Homepage-Instructors-Instructors-Other-Other'),
#  (334108, 2917116, 'monthly', 'Log in-Log in'),
#  (334108, 2917333, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (380790, 2917749, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (338124, 2918225, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (456808, 2919079, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (314728, 2923205, 'monthly', 'Log in-Log in'),
#  (291598, 2923244, 'annual', 'Homepage-Homepage'),
#  (314728, 2923711, 'monthly', 'Other-Other-Other-Other'),
#  (343534, 2925690, 'monthly', 'Homepage-Homepage'),
#  (343534, 2925764, 'monthly', 'Sign up-Sign up-Sign up-Sign up'),
#  (334108, 2928696, 'monthly', 'Log in-Log in'),
#  (262999, 2932577, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (456907, 2932786, 'monthly', 'Other-Other'),
#  (349826, 2934814, 'annual', 'Resources center-Resources center'),
#  (349826, 2935381, 'annual', 'Resources center-Resources center'),
#  (312849, 2935579, 'annual', 'Log in-Log in'),
#  (469721, 2935962, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (349826, 2936139, 'annual', 'Homepage-Homepage'),
#  (466537, 2937145, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses'),
#  (466537, 2937157, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (456953, 2937302, 'annual', 'Resources center-Resources center-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (278257, 2937678, 'annual', 'Log in-Log in'),
#  (263101, 2937684, 'annual', 'Homepage-Homepage-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate'),
#  (263101, 2937920, 'annual', 'Homepage-Homepage-Pricing-Pricing'),
#  (456907, 2938891, 'monthly', 'Log in-Log in'),
#  (334108, 2940252, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (456993, 2941397, 'annual', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up'),
#  (334108, 2943866, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (296305, 2951029, 'annual', 'Homepage-Homepage-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources ce ... (263 characters truncated) ... ources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center'),
#  (296305, 2951040, 'annual', 'Resources center-Resources center'),
#  (296305, 2951204, 'annual', 'Resources center-Resources center'),
#  (456100, 2952235, 'annual', 'Homepage-Homepage-Upcoming courses-Upcoming courses-Courses-Courses-Courses-Courses-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate'),
#  (307149, 2952947, 'annual', 'Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Career tracks-Career tracks-Homepage-Homepage-Homepage-Homepage-Career tracks ... (61 characters truncated) ... cks-Career tracks-Career tracks-Career tracks-Courses-Courses-Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Pricing-Pricing'),
#  (334108, 2958311, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (394304, 2959203, 'annual', 'Log in-Log in-Log in-Log in'),
#  (334108, 2959233, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (398805, 2960310, 'monthly', 'Log in-Log in'),
#  (37614, 2960407, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (37614, 2960417, 'annual', 'Checkout-Checkout'),
#  (295174, 2961840, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (457261, 2962725, 'monthly', 'Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (314632, 2963084, 'annual', 'Log in-Log in'),
#  (272443, 2964719, 'monthly', 'Log in-Log in'),
#  (334108, 2968626, 'monthly', 'Log in-Log in'),
#  (458421, 2969276, 'quarterly', 'Homepage-Homepage-Pricing-Pricing-Homepage-Homepage'),
#  (334108, 2969379, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (456953, 2969481, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (142012, 2969507, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (295049, 2970799, 'annual', 'Homepage-Homepage-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career ... (63 characters truncated) ... icate-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses'),
#  (295049, 2970819, 'annual', 'Courses-Courses'),
#  (267955, 2978149, 'annual', 'Homepage-Homepage-Upcoming courses-Upcoming courses-Pricing-Pricing'),
#  (334108, 2978232, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (413937, 2978781, 'monthly', 'Log in-Log in'),
#  (316287, 2980148, 'annual', 'Log in-Log in'),
#  (1516, 2980231, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (1516, 2980248, 'annual', 'Other-Other-Sign up-Sign up-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (457417, 2980320, 'monthly', 'Log in-Log in-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (334108, 2982124, 'monthly', 'Log in-Log in'),
#  (333415, 2983320, 'monthly', 'Log in-Log in'),
#  (454953, 2984198, 'monthly', 'Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (454953, 2984207, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (448260, 2984303, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (371060, 2984971, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (267955, 2985189, 'annual', 'Homepage-Homepage-Pricing-Pricing'),
#  (331693, 2985250, 'monthly', 'Log in-Log in'),
#  (331693, 2985256, 'monthly', 'Log in-Log in'),
#  (305842, 2986723, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (456277, 2990029, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in'),
#  (466591, 2991864, 'quarterly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (1516, 2992252, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (457609, 2994305, 'annual', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (387813, 2999822, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (312347, 3006181, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (331693, 3009269, 'monthly', 'Log in-Log in'),
#  (143885, 3010869, 'annual', 'Resources center-Resources center-Resources center-Resources center-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (334108, 3011839, 'monthly', 'Log in-Log in'),
#  (324442, 3019778, 'monthly', 'Log in-Log in'),
#  (454953, 3021787, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (454953, 3021844, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (454953, 3023008, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (343534, 3023030, 'monthly', 'Log in-Log in'),
#  (302942, 3023299, 'annual', 'Log in-Log in'),
#  (102461, 3023818, 'annual', 'Instructors-Instructors-Pricing-Pricing'),
#  (343534, 3024359, 'monthly', 'Log in-Log in'),
#  (343534, 3024842, 'monthly', 'Log in-Log in'),
#  (343534, 3025018, 'monthly', 'Log in-Log in'),
#  (343534, 3025023, 'monthly', 'Log in-Log in'),
#  (307149, 3025309, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Homepage-Homepage-Homepage-Homepage-Courses-Courses-Courses-Courses-Other-Other-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing-Courses-Courses-Courses-Courses'),
#  (343534, 3025489, 'monthly', 'Log in-Log in'),
#  (367711, 3027273, 'annual', 'Pricing-Pricing-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (463014, 3027287, 'annual', 'Homepage-Homepage'),
#  (305785, 3028990, 'annual', 'Courses-Courses'),
#  (463200, 3030376, 'monthly', 'Log in-Log in'),
#  (463200, 3030475, 'monthly', 'Checkout-Checkout-Checkout-Checkout'),
#  (291598, 3032705, 'annual', 'Homepage-Homepage'),
#  (331693, 3034628, 'monthly', 'Log in-Log in'),
#  (331693, 3034778, 'monthly', 'Log in-Log in'),
#  (331693, 3034815, 'monthly', 'Log in-Log in'),
#  (266371, 3037169, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (282927, 3037573, 'annual', 'Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (315107, 3040314, 'annual', 'Homepage-Homepage-Pricing-Pricing-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (466643, 3040825, 'annual', 'Homepage-Homepage-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career ... (291 characters truncated) ... tificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Pricing-Pricing'),
#  (349826, 3041702, 'annual', 'Log in-Log in'),
#  (312347, 3042488, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (398805, 3047316, 'monthly', 'Log in-Log in'),
#  (454953, 3050782, 'monthly', 'Other-Other-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (458068, 3051442, 'quarterly', 'Log in-Log in-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (343534, 3059220, 'monthly', 'Log in-Log in'),
#  (314632, 3059320, 'annual', 'Log in-Log in'),
#  (431959, 3063057, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (456993, 3064312, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (437976, 3067104, 'monthly', 'Checkout-Checkout'),
#  (458068, 3069078, 'quarterly', 'Log in-Log in'),
#  (458068, 3069813, 'quarterly', 'Log in-Log in-Log in-Log in'),
#  (448260, 3069979, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (1516, 3070491, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (343534, 3074966, 'monthly', 'Sign up-Sign up-Sign up-Sign up'),
#  (343534, 3075138, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (312849, 3075174, 'annual', 'Instructors-Instructors'),
#  (343534, 3075227, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up'),
#  (376948, 3078323, 'monthly', 'Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (376948, 3078392, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (353669, 3080189, 'monthly', 'Log in-Log in'),
#  (454953, 3080211, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (296653, 3080533, 'annual', 'Courses-Courses-Log in-Log in'),
#  (333415, 3080815, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (324442, 3080855, 'monthly', 'Log in-Log in'),
#  (455122, 3081602, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (458392, 3086238, 'annual', 'Log in-Log in'),
#  (465532, 3086788, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (343534, 3086811, 'monthly', 'Homepage-Homepage'),
#  (454953, 3088117, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (458421, 3089808, 'quarterly', 'Homepage-Homepage-Sign up-Sign up'),
#  (458421, 3089845, 'quarterly', 'Sign up-Sign up-Sign up-Sign up'),
#  (352062, 3093513, 'annual', 'Log in-Log in'),
#  (422145, 3097083, 'annual', 'Log in-Log in'),
#  (352062, 3098289, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (413937, 3106396, 'monthly', 'Log in-Log in-Log in-Log in'),
#  (338632, 3110680, 'monthly', 'Homepage-Homepage-Pricing-Pricing-Pricing-Pricing'),
#  (267955, 3112051, 'annual', 'Resources center-Resources center-Courses-Courses'),
#  (426843, 3112460, 'annual', 'Log in-Log in'),
#  (398805, 3114144, 'monthly', 'Homepage-Homepage-Homepage-Homepage-Log in-Log in'),
#  (289379, 3114408, 'quarterly', 'Log in-Log in-Log in-Log in'),
#  (361114, 3115445, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (458604, 3122406, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (458604, 3122433, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up'),
#  (334108, 3126143, 'monthly', 'Log in-Log in'),
#  (398805, 3132016, 'monthly', 'Log in-Log in'),
#  (352062, 3132330, 'annual', 'Log in-Log in'),
#  (399029, 3132886, 'monthly', 'Pricing-Pricing-Course certificate-Course certificate-Log in-Log in'),
#  (120485, 3133194, 'monthly', 'Homepage-Homepage-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing'),
#  (465102, 3135232, 'annual', 'Other-Other-Other-Other-Other-Other-Other-Other-Other-Other-Other-Other-Other-Other-Log in-Log in-Log in-Log in'),
#  (355056, 3138327, 'annual', 'Courses-Courses-Pricing-Pricing-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Career tracks-Career tracks'),
#  (456993, 3138771, 'annual', 'Log in-Log in'),
#  (334108, 3140492, 'monthly', 'Log in-Log in'),
#  (371779, 3140623, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (228059, 3144211, 'annual', 'Log in-Log in'),
#  (465532, 3149105, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (465532, 3149158, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (465532, 3149392, 'annual', 'Homepage-Homepage-Courses-Courses'),
#  (266371, 3151521, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Sign up-Sign up-Log in-Log in-Log in-Log in'),
#  (334108, 3152217, 'monthly', 'Log in-Log in-Log in-Log in'),
#  (157143, 3152368, 'annual', 'Pricing-Pricing'),
#  (343534, 3152426, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (343534, 3152435, 'monthly', 'Sign up-Sign up-Sign up-Sign up'),
#  (431537, 3153566, 'monthly', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (431537, 3153638, 'monthly', 'Courses-Courses'),
#  (431537, 3153684, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (431537, 3153701, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (458926, 3156331, 'annual', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up'),
#  (458926, 3156404, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in'),
#  (458926, 3156409, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (458926, 3156412, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (458926, 3156416, 'annual', 'Log in-Log in'),
#  (458926, 3156508, 'annual', 'Log in-Log in'),
#  (430496, 3158751, 'monthly', 'Log in-Log in-Log in-Log in'),
#  (456953, 3162721, 'annual', 'Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Career tracks-Career tracks-Career tracks-Career tracks-Homepage-Homepage-Career tracks-Career tracks-Career tracks-Career tracks'),
#  (467213, 3163929, 'annual', 'Homepage-Homepage-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing'),
#  (338632, 3163984, 'monthly', 'Homepage-Homepage-Pricing-Pricing-Pricing-Pricing-Courses-Courses-Courses-Courses-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (402831, 3168279, 'annual', 'Log in-Log in'),
#  (402831, 3168294, 'annual', 'Log in-Log in'),
#  (228059, 3171623, 'annual', 'Log in-Log in'),
#  (392285, 3173677, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (465532, 3176036, 'annual', 'Homepage-Homepage-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Pricing-Pricing'),
#  (343534, 3176658, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (343534, 3177046, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (157143, 3179670, 'annual', 'Log in-Log in'),
#  (284423, 3179877, 'annual', 'Homepage-Homepage'),
#  (398805, 3181263, 'monthly', 'Log in-Log in'),
#  (459141, 3182712, 'monthly', 'Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (459147, 3183260, 'annual', 'Other-Other'),
#  (437976, 3184235, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (331693, 3185487, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (331693, 3185489, 'monthly', 'Log in-Log in'),
#  (331693, 3185493, 'monthly', 'Log in-Log in'),
#  (459170, 3186092, 'annual', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (392285, 3193010, 'monthly', 'Log in-Log in-Log in-Log in'),
#  (466394, 3194790, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (458068, 3195424, 'quarterly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (272443, 3196343, 'monthly', 'Log in-Log in'),
#  (349826, 3199315, 'annual', 'Resources center-Resources center'),
#  (448776, 3199779, 'annual', 'Resources center-Resources center'),
#  (282998, 3200335, 'annual', 'Log in-Log in-Log in-Log in'),
#  (356489, 3201294, 'annual', 'Log in-Log in'),
#  (152002, 3201734, 'annual', 'Log in-Log in-Log in-Log in'),
#  (456953, 3202026, 'annual', 'Resources center-Resources center'),
#  (310357, 3202454, 'annual', 'Resources center-Resources center-Other-Other-Other-Other-Sign up-Sign up-Sign up-Sign up'),
#  (310357, 3202623, 'annual', 'Coupon-Coupon'),
#  (306397, 3203185, 'annual', 'Resources center-Resources center'),
#  (469721, 3203763, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (344014, 3204105, 'annual', 'Resources center-Resources center-Other-Other-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (459141, 3205701, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (472929, 3205827, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (353878, 3206609, 'monthly', 'Resources center-Resources center'),
#  (289919, 3206997, 'monthly', 'Resources center-Resources center'),
#  (338632, 3208175, 'monthly', 'Resources center-Resources center-Other-Other-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (289919, 3208226, 'monthly', 'Resources center-Resources center-Pricing-Pricing-Pricing-Pricing'),
#  (152002, 3209321, 'annual', 'Resources center-Resources center-Other-Other'),
#  (458392, 3209445, 'annual', 'Resources center-Resources center-Log in-Log in'),
#  (412594, 3209446, 'monthly', 'Log in-Log in'),
#  (398805, 3210020, 'monthly', 'Log in-Log in'),
#  (462514, 3210199, 'quarterly', 'Sign up-Sign up-Log in-Log in'),
#  (459364, 3210988, 'annual', 'Pricing-Pricing-Checkout-Checkout-Homepage-Homepage-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Sign up-Sign up-Sign up-Sign up'),
#  (269209, 3212142, 'annual', 'Resources center-Resources center-Log in-Log in'),
#  (269209, 3212152, 'annual', 'Resources center-Resources center-Log in-Log in-Log in-Log in'),
#  (367711, 3212677, 'annual', 'Resources center-Resources center'),
#  (355056, 3213227, 'annual', 'Resources center-Resources center'),
#  (267955, 3215064, 'annual', 'Resources center-Resources center'),
#  (459409, 3215147, 'annual', 'Other-Other-Career tracks-Career tracks-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (344014, 3216441, 'annual', 'Log in-Log in'),
#  (293945, 3216449, 'annual', 'Resources center-Resources center'),
#  (334108, 3218089, 'monthly', 'Log in-Log in'),
#  (334108, 3218212, 'monthly', 'Log in-Log in'),
#  (459141, 3219950, 'monthly', 'Homepage-Homepage-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Sign up-Sign up-Log in-Log in-Log in-Log in'),
#  (334108, 3220587, 'monthly', 'Log in-Log in'),
#  (459494, 3220622, 'monthly', 'Other-Other'),
#  (352062, 3221257, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (459526, 3224231, 'annual', 'Homepage-Homepage-Career track certificate-Career track certificate-Sign up-Sign up-Sign up-Sign up'),
#  (459560, 3226568, 'monthly', 'Homepage-Homepage-Career tracks-Career tracks-Pricing-Pricing-Pricing-Pricing-Pricing-Pricing-Courses-Courses-Courses-Courses-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (331693, 3227445, 'monthly', 'Log in-Log in'),
#  (261077, 3227814, 'annual', 'Resources center-Resources center'),
#  (367401, 3227962, 'annual', 'Resources center-Resources center'),
#  (367401, 3228122, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks'),
#  (465532, 3229205, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (37614, 3229791, 'annual', 'Homepage-Homepage-Courses-Courses'),
#  (463421, 3230346, 'annual', 'Homepage-Homepage-Pricing-Pricing'),
#  (313048, 3230443, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (465609, 3231689, 'monthly', 'Homepage-Homepage-Pricing-Pricing-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Pricing ... (79 characters truncated) ...  tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage'),
#  (289919, 3231825, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (465609, 3231859, 'monthly', 'Homepage-Homepage-Courses-Courses'),
#  (409923, 3232165, 'annual', 'Career tracks-Career tracks-Career tracks-Career tracks-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate'),
#  (409923, 3232252, 'annual', 'Pricing-Pricing'),
#  (343534, 3232868, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (322577, 3239642, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (283073, 3240907, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (459560, 3241072, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (424647, 3241219, 'annual', 'Log in-Log in'),
#  (456261, 3242064, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (401176, 3243929, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (334108, 3244289, 'monthly', 'Log in-Log in'),
#  (459756, 3245455, 'annual', 'Homepage-Homepage-Courses-Courses-Pricing-Pricing-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (343534, 3245465, 'monthly', 'Homepage-Homepage'),
#  (459756, 3245516, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (459756, 3245823, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (459756, 3246186, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (459756, 3246246, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (343534, 3246932, 'monthly', 'Log in-Log in'),
#  (312454, 3247376, 'monthly', 'Homepage-Homepage-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Caree ... (57 characters truncated) ...  tracks-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Log in-Log in'),
#  (466394, 3248050, 'annual', 'Courses-Courses'),
#  (456261, 3249686, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (289370, 3249941, 'monthly', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (364769, 3250894, 'monthly', 'Coupon-Coupon-Coupon-Coupon'),
#  (398805, 3254776, 'monthly', 'Log in-Log in'),
#  (466394, 3255694, 'annual', 'Courses-Courses-Courses-Courses-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Instructors-Instructors'),
#  (466394, 3255780, 'annual', 'Coupon-Coupon'),
#  (283073, 3257169, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (344014, 3258568, 'annual', 'Blog-Blog'),
#  (459946, 3259212, 'annual', 'Homepage-Homepage-Pricing-Pricing-Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks'),
#  (459946, 3259240, 'annual', 'Courses-Courses-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (454131, 3260495, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (312849, 3261268, 'annual', 'Resources center-Resources center'),
#  (312849, 3261378, 'annual', 'Resources center-Resources center'),
#  (371060, 3262704, 'monthly', 'Other-Other'),
#  (272443, 3262828, 'monthly', 'Resources center-Resources center-Log in-Log in'),
#  (459494, 3263019, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (459756, 3264125, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (444322, 3265090, 'quarterly', 'Homepage-Homepage-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (444322, 3265149, 'quarterly', 'Checkout-Checkout'),
#  (456261, 3266112, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (466591, 3266142, 'quarterly', 'Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center'),
#  (459946, 3267279, 'annual', 'Homepage-Homepage-Pricing-Pricing-Log in-Log in'),
#  (459946, 3267355, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (460122, 3270022, 'monthly', 'Homepage-Homepage'),
#  (460122, 3270030, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up'),
#  (412594, 3271698, 'monthly', 'Log in-Log in'),
#  (461171, 3272708, 'quarterly', 'Other-Other-Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks'),
#  (465532, 3273978, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (291598, 3274493, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (398805, 3274832, 'monthly', 'Log in-Log in'),
#  (453696, 3282300, 'monthly', 'Homepage-Homepage-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career ... (11 characters truncated) ... ificate-Career track certificate-Career track certificate-Career tracks-Career tracks-Courses-Courses-Courses-Courses-Courses-Courses-Pricing-Pricing'),
#  (456261, 3282405, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (312849, 3283413, 'annual', 'Pricing-Pricing-Log in-Log in'),
#  (459170, 3283820, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (459170, 3283845, 'annual', 'Log in-Log in-Log in-Log in'),
#  (361752, 3286687, 'monthly', 'Homepage-Homepage-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Pricing-Pricing-Pricing-Pricing-Log in-Log in'),
#  (460480, 3288653, 'annual', 'Other-Other'),
#  (465191, 3290009, 'monthly', 'Career tracks-Career tracks'),
#  (465191, 3290282, 'monthly', 'Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses'),
#  (465191, 3290436, 'monthly', 'Pricing-Pricing-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (466444, 3292103, 'annual', 'Log in-Log in'),
#  (466444, 3292136, 'annual', 'Resources center-Resources center-Other-Other'),
#  (338632, 3292363, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Log in-Log in-Log in-Log in'),
#  (398805, 3292614, 'monthly', 'Log in-Log in'),
#  (453489, 3293809, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (459364, 3295365, 'annual', 'Homepage-Homepage-Pricing-Pricing-Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (459364, 3295630, 'annual', 'Log in-Log in'),
#  (282927, 3296846, 'annual', 'Courses-Courses-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (343619, 3297145, 'annual', 'Homepage-Homepage'),
#  (272443, 3298889, 'monthly', 'Log in-Log in'),
#  (468715, 3300007, 'annual', 'Homepage-Homepage-Pricing-Pricing-Resources center-Resources center-Resources center-Resources center-Resources center-Resources center-Resources cen ... (309 characters truncated) ... reer tracks-Career tracks-Career tracks-Career tracks-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (460665, 3300415, 'annual', 'Homepage-Homepage-Sign up-Sign up-Pricing-Pricing-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (402831, 3303507, 'annual', 'Log in-Log in'),
#  (353878, 3308030, 'monthly', 'Log in-Log in'),
#  (353878, 3308042, 'monthly', 'Log in-Log in'),
#  (466537, 3308454, 'annual', 'Homepage-Homepage'),
#  (427084, 3311363, 'monthly', 'Log in-Log in'),
#  (399029, 3311611, 'monthly', 'Other-Other-Log in-Log in'),
#  (343619, 3311881, 'annual', 'Homepage-Homepage'),
#  (461311, 3313494, 'annual', 'Homepage-Homepage-Homepage-Homepage-Career tracks-Career tracks-Course certificate-Course certificate-Course certificate-Course certificate-Course ce ... (55 characters truncated) ... urses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Pricing-Pricing-Pricing-Pricing'),
#  (461311, 3313991, 'annual', 'Homepage-Homepage-Career tracks-Career tracks-Homepage-Homepage-Career tracks-Career tracks'),
#  (459756, 3315047, 'annual', 'Checkout-Checkout-Checkout-Checkout'),
#  (460879, 3316171, 'quarterly', 'Homepage-Homepage-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate'),
#  (444322, 3316366, 'quarterly', 'Homepage-Homepage-Log in-Log in-Log in-Log in'),
#  (460879, 3316442, 'quarterly', 'Upcoming courses-Upcoming courses-Resources center-Resources center-Resources center-Resources center-Other-Other-Sign up-Sign up-Sign up-Sign up'),
#  (468715, 3316733, 'annual', 'Homepage-Homepage-Upcoming courses-Upcoming courses'),
#  (456261, 3317515, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (465191, 3317690, 'monthly', 'Courses-Courses-Courses-Courses'),
#  (426843, 3317995, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (459494, 3319319, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (296546, 3319429, 'monthly', 'Log in-Log in'),
#  (460950, 3320751, 'monthly', 'Homepage-Homepage-Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Pricing-Pricing-Career track certificate-Career track certi ... (1 characters truncated) ... icate-Courses-Courses-Courses-Courses-Courses-Courses-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (460879, 3321225, 'quarterly', 'Log in-Log in'),
#  (292620, 3321766, 'annual', 'Homepage-Homepage-Career track certificate-Career track certificate'),
#  (289370, 3322767, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (460879, 3323004, 'quarterly', 'Checkout-Checkout'),
#  (289370, 3323825, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (272443, 3323828, 'monthly', 'Log in-Log in'),
#  (289370, 3323951, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (289370, 3324078, 'monthly', 'Log in-Log in-Sign up-Sign up-Sign up-Sign up-Log in-Log in'),
#  (289370, 3324082, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (465532, 3324215, 'annual', 'Homepage-Homepage-Pricing-Pricing-Upcoming courses-Upcoming courses-Resources center-Resources center'),
#  (343619, 3324527, 'annual', 'Homepage-Homepage-Pricing-Pricing-Log in-Log in-Log in-Log in'),
#  (299103, 3324802, 'annual', 'Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (299103, 3324830, 'annual', 'Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Log in-Log in-Sign up-Sign up-Log in-Log in'),
#  (461029, 3324952, 'annual', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (461046, 3325349, 'annual', 'Courses-Courses-Sign up-Sign up-Sign up-Sign up'),
#  (465532, 3325411, 'annual', 'Homepage-Homepage-Courses-Courses-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Courses-Courses-Course certificate-Course c ... (541 characters truncated) ... tificate-Career track certificate-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses-Courses-Courses'),
#  (294736, 3326442, 'annual', 'Homepage-Homepage-Pricing-Pricing-Courses-Courses-Homepage-Homepage'),
#  (294736, 3326446, 'annual', 'Career tracks-Career tracks'),
#  (460950, 3326842, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (461865, 3329253, 'monthly', 'Homepage-Homepage-Pricing-Pricing-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Cou ... (113 characters truncated) ... urses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Pricing-Pricing'),
#  (461150, 3329437, 'annual', 'Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (461150, 3329502, 'annual', 'Checkout-Checkout-Checkout-Checkout'),
#  (461150, 3329524, 'annual', 'Checkout-Checkout'),
#  (307886, 3330193, 'monthly', 'Homepage-Homepage'),
#  (461171, 3330516, 'quarterly', 'Career tracks-Career tracks-Sign up-Sign up-Sign up-Sign up'),
#  (461171, 3330667, 'quarterly', 'Log in-Log in'),
#  (460879, 3331232, 'quarterly', 'Log in-Log in'),
#  (398805, 3331358, 'monthly', 'Log in-Log in'),
#  (289370, 3331697, 'monthly', 'Log in-Log in-Sign up-Sign up-Log in-Log in'),
#  (289370, 3331699, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (289370, 3332089, 'monthly', 'Log in-Log in'),
#  (289370, 3332135, 'monthly', 'Log in-Log in'),
#  (289370, 3332161, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (316287, 3332612, 'annual', 'Log in-Log in'),
#  (289370, 3332853, 'monthly', 'Log in-Log in'),
#  (289370, 3332856, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (459526, 3332905, 'annual', 'Homepage-Homepage-Pricing-Pricing-Log in-Log in'),
#  (108970, 3333726, 'annual', 'Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Career tracks-Career tracks-Homepage-Homepage-Homepage-Homepage-Career tracks-Career tracks-Homepage-Homepage'),
#  (398805, 3333880, 'monthly', 'Log in-Log in'),
#  (398805, 3333888, 'monthly', 'Log in-Log in'),
#  (456261, 3334257, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (461311, 3335379, 'annual', 'Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (444322, 3335749, 'quarterly', 'Homepage-Homepage-Pricing-Pricing-Pricing-Pricing-Log in-Log in-Log in-Log in'),
#  (461311, 3335898, 'annual', 'Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (460950, 3336144, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (460122, 3336220, 'monthly', 'Log in-Log in'),
#  (291598, 3336895, 'annual', 'Homepage-Homepage'),
#  (295174, 3337200, 'monthly', 'Homepage-Homepage-Pricing-Pricing'),
#  (333415, 3337592, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (461311, 3338171, 'annual', 'Courses-Courses-Courses-Courses-Log in-Log in-Log in-Log in-Log in-Log in'),
# ...
#  (456261, 3425102, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (456261, 3425115, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (456261, 3425137, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (462919, 3425204, 'annual', 'Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Homepage-Courses-Courses-Career tracks-Career tracks-Career tracks-C ... (137 characters truncated) ... urses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (462919, 3425361, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (462919, 3425371, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (465532, 3425510, 'annual', 'Homepage-Homepage-Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (463172, 3425585, 'annual', 'Pricing-Pricing-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career tracks-Career tracks-Caree ... (589 characters truncated) ... ses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Resources center-Resources center-Pricing-Pricing'),
#  (456261, 3425630, 'monthly', 'Checkout-Checkout-Checkout-Checkout'),
#  (456261, 3425667, 'monthly', 'Checkout-Checkout'),
#  (465532, 3425680, 'annual', 'Homepage-Homepage-Courses-Courses'),
#  (462930, 3425692, 'annual', 'Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon'),
#  (462930, 3425717, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (463172, 3425986, 'annual', 'Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tr ... (37 characters truncated) ... er tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks'),
#  (456261, 3426339, 'monthly', 'Checkout-Checkout-Checkout-Checkout'),
#  (273256, 3426498, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (465532, 3426504, 'annual', 'Courses-Courses'),
#  (408209, 3426760, 'monthly', 'Checkout-Checkout'),
#  (465532, 3426984, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (158113, 3426995, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in'),
#  (465532, 3427131, 'annual', 'Homepage-Homepage'),
#  (462967, 3427154, 'annual', 'Other-Other'),
#  (462971, 3427164, 'annual', 'Homepage-Homepage-Career track certificate-Career track certificate-Homepage-Homepage-Homepage-Homepage-Career track certificate-Career track certifi ... (115 characters truncated) ... ck certificate-Career track certificate-Career track certificate-Career track certificate-Career tracks-Career tracks-Sign up-Sign up-Sign up-Sign up'),
#  (462971, 3427423, 'annual', 'Other-Other-Resources center-Resources center'),
#  (466468, 3427510, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (465532, 3427756, 'annual', 'Homepage-Homepage-Courses-Courses-Courses-Courses'),
#  (462667, 3427769, 'annual', 'Log in-Log in-Log in-Log in'),
#  (158113, 3427842, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (461995, 3427945, 'annual', 'Coupon-Coupon'),
#  (461995, 3427951, 'annual', 'Coupon-Coupon'),
#  (464483, 3428124, 'monthly', 'Homepage-Homepage-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Homepage-Homepage-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate-Course certificate'),
#  (462281, 3428339, 'monthly', 'Other-Other-Other-Other-Log in-Log in'),
#  (462281, 3428346, 'monthly', 'Checkout-Checkout'),
#  (462281, 3428427, 'monthly', 'Homepage-Homepage-Log in-Log in'),
#  (462281, 3428472, 'monthly', 'Log in-Log in'),
#  (462281, 3428475, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (461458, 3428517, 'annual', 'Pricing-Pricing'),
#  (463014, 3428591, 'annual', 'Homepage-Homepage-Pricing-Pricing-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Car ... (915 characters truncated) ... reer tracks-Career track certificate-Career track certificate-Career tracks-Career tracks-Career tracks-Career tracks-Sign up-Sign up-Sign up-Sign up'),
#  (286986, 3428596, 'annual', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (286986, 3428600, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (289379, 3428643, 'quarterly', 'Homepage-Homepage-Courses-Courses'),
#  (289379, 3428646, 'quarterly', 'Homepage-Homepage-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Sign up-Sign up-Log in-Log in'),
#  (462541, 3428758, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (463014, 3428903, 'annual', 'Checkout-Checkout'),
#  (463277, 3429023, 'quarterly', 'Homepage-Homepage-Pricing-Pricing-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track ce ... (35 characters truncated) ... Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate'),
#  (463277, 3429049, 'quarterly', 'Career track certificate-Career track certificate-Career tracks-Career tracks-Career tracks-Career tracks-Pricing-Pricing-Career tracks-Career tracks ... (501 characters truncated) ... s-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Career tracks-Career tracks-Courses-Courses-Courses-Courses-Courses-Courses-Courses-Courses'),
#  (474142, 3429566, 'annual', 'Homepage-Homepage-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate-Career track certificate'),
#  (376948, 3429880, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (462672, 3430177, 'annual', 'Checkout-Checkout'),
#  (456261, 3430246, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (456261, 3430255, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (462281, 3430542, 'monthly', 'Log in-Log in'),
#  (462281, 3430564, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (462281, 3430746, 'monthly', 'Log in-Log in'),
#  (462281, 3430748, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (462281, 3430765, 'monthly', 'Log in-Log in'),
#  (462281, 3430769, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (462884, 3430801, 'annual', 'Homepage-Homepage-Log in-Log in'),
#  (267955, 3431391, 'annual', 'Coupon-Coupon-Coupon-Coupon'),
#  (462643, 3431531, 'annual', 'Courses-Courses-Log in-Log in'),
#  (305842, 3431569, 'monthly', 'Other-Other-Log in-Log in'),
#  (462643, 3431708, 'annual', 'Coupon-Coupon-Coupon-Coupon-Coupon-Coupon'),
#  (384062, 3431776, 'annual', 'Log in-Log in'),
#  (462967, 3431976, 'annual', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (462221, 3432044, 'monthly', 'Checkout-Checkout'),
#  (462221, 3432045, 'monthly', 'Checkout-Checkout'),
#  (467212, 3432046, 'annual', 'Homepage-Homepage'),
#  (462670, 3432059, 'quarterly', 'Log in-Log in'),
#  (305842, 3432437, 'monthly', 'Checkout-Checkout-Checkout-Checkout'),
#  (463084, 3432511, 'monthly', 'Other-Other'),
#  (467689, 3432775, 'annual', 'Career tracks-Career tracks-Course certificate-Course certificate-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks ... (11 characters truncated) ... cks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Courses-Courses-Pricing-Pricing-Pricing-Pricing'),
#  (463084, 3432791, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (462077, 3432840, 'monthly', 'Coupon-Coupon-Coupon-Coupon-Coupon-Coupon'),
#  (467212, 3432872, 'annual', 'Pricing-Pricing-Checkout-Checkout-Checkout-Checkout-Homepage-Homepage'),
#  (467212, 3432989, 'annual', 'Homepage-Homepage'),
#  (467212, 3432998, 'annual', 'Homepage-Homepage'),
#  (444322, 3433571, 'quarterly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (444322, 3433630, 'quarterly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (444322, 3433687, 'quarterly', 'Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (444322, 3433758, 'quarterly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (444322, 3433784, 'quarterly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (319252, 3433856, 'monthly', 'Log in-Log in-Log in-Log in'),
#  (463110, 3433912, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up'),
#  (463116, 3434146, 'monthly', 'Other-Other-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (463116, 3434464, 'monthly', 'Log in-Log in'),
#  (463110, 3434657, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (457261, 3434855, 'monthly', 'Log in-Log in'),
#  (457261, 3434901, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (424647, 3435101, 'annual', 'Homepage-Homepage-Sign up-Sign up-Log in-Log in'),
#  (462890, 3435156, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (462890, 3435171, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (457261, 3435201, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (424647, 3435421, 'annual', 'Homepage-Homepage-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Sign up-Sign up-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (465532, 3435547, 'annual', 'Homepage-Homepage-Other-Other-Coupon-Coupon-Homepage-Homepage-Pricing-Pricing-Checkout-Checkout-Homepage-Homepage-Pricing-Pricing'),
#  (424647, 3435579, 'annual', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Check ... (151 characters truncated) ... ckout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (424647, 3435914, 'annual', 'Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon'),
#  (333415, 3435919, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (424647, 3435934, 'annual', 'Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon'),
#  (424647, 3435983, 'annual', 'Coupon-Coupon'),
#  (462971, 3436381, 'annual', 'Log in-Log in'),
#  (424647, 3436472, 'annual', 'Coupon-Coupon-Coupon-Coupon-Coupon-Coupon'),
#  (424647, 3436487, 'annual', 'Coupon-Coupon-Coupon-Coupon'),
#  (466821, 3436747, 'annual', 'Courses-Courses-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Pricing-Pricing-Prici ... (499 characters truncated) ... er tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks-Career tracks'),
#  (456261, 3436783, 'monthly', 'Checkout-Checkout-Checkout-Checkout'),
#  (463172, 3436867, 'annual', 'Career tracks-Career tracks-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (462281, 3437132, 'monthly', 'Log in-Log in'),
#  (462281, 3437137, 'monthly', 'Checkout-Checkout'),
#  (444322, 3437245, 'quarterly', 'Log in-Log in-Log in-Log in'),
#  (324442, 3437256, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (444322, 3437275, 'quarterly', 'Homepage-Homepage-Log in-Log in'),
#  (444322, 3437288, 'quarterly', 'Checkout-Checkout'),
#  (463172, 3437475, 'annual', 'Homepage-Homepage'),
#  (463172, 3437565, 'annual', 'Checkout-Checkout'),
#  (463116, 3437614, 'monthly', 'Log in-Log in'),
#  (463183, 3437747, 'annual', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (463116, 3437956, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in'),
#  (463200, 3438684, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (463200, 3439057, 'monthly', 'Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (463226, 3439467, 'annual', 'Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon-Coupon'),
#  (463224, 3439477, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (463224, 3439524, 'monthly', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (463224, 3439530, 'monthly', 'Checkout-Checkout-Checkout-Checkout'),
#  (463224, 3439543, 'monthly', 'Checkout-Checkout'),
#  (463227, 3439587, 'monthly', 'Homepage-Homepage-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up-Sign up'),
#  (463227, 3439607, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (463116, 3439736, 'monthly', 'Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout-Checkout'),
#  (411785, 3439858, 'annual', 'Log in-Log in-Log in-Log in'),
#  (462720, 3439927, 'monthly', 'Courses-Courses-Sign up-Sign up'),
#  (462720, 3440152, 'monthly', 'Sign up-Sign up-Sign up-Sign up'),
#  (411342, 3440295, 'monthly', 'Log in-Log in-Sign up-Sign up-Log in-Log in'),
#  (463172, 3440327, 'annual', 'Homepage-Homepage-Log in-Log in-Log in-Log in-Log in-Log in-Log in-Log in'),
#  (463172, 3440356, 'annual', 'Checkout-Checkout'),
#  ...]

# %% [markdown]
# # Conclusion
# This SQL project successfully extracted user journey data for paying customers, revealing the sequence of web page interactions leading to their first purchase. The process included filtering by purchase date, excluding test users, replacing URLs with readable aliases, and grouping sessions into user journeys. This data provides valuable insights into user behavior before converting to paying customers.
#
# The final output can be exported as a CSV file, which can further be used for analysis in tools like Excel or Power BI to uncover patterns that could help improve the customer journey and enhance marketing efforts.
